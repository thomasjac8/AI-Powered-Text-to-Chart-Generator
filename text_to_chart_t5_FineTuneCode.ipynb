# %%
# !nvidia-smi
# Out:
# Wed Jul 30 10:09:06 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0             47W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# This get the RAPIDS-Colab install files and test check your GPU.  Run this and the next cell only.
# Please read the output of this cell.  If your Colab Instance is not RAPIDS compatible, it will warn you and give you remediation steps.
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# !python rapidsai-csp-utils/colab/pip-install.py
# Out:
# Cloning into 'rapidsai-csp-utils'...
# remote: Enumerating objects: 597, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 597 (delta 128), reused 82 (delta 82), pack-reused 434 (from 3)
# Receiving objects: 100% (597/597), 196.59 KiB | 24.57 MiB/s, done.
# Resolving deltas: 100% (302/302), done.
# Installing RAPIDS remaining 25.04 libraries
# Using Python 3.11.13 environment at: /usr
# Resolved 175 packages in 13.57s
# ...
#  Downloaded cudf-cu12
#  Downloaded libkvikio-cu12
#  Downloaded shapely
#  Downloaded rmm-cu12
#  Downloaded datashader
#  Downloaded dask
#  Downloaded ucx-py-cu12
#  Downloaded cugraph-cu12
#  Downloaded pylibcugraph-cu12
#  Downloaded cuspatial-cu12
#  Downloaded bokeh
#  Downloaded librmm-cu12
#  Downloaded cuproj-cu12
#  Downloaded cuml-cu12
#  Downloaded cucim-cu12
#  Downloaded libcuspatial-cu12
#  Downloaded pylibcudf-cu12
#  Downloaded nvidia-nvcomp-cu12
#  Downloaded libraft-cu12
# ...

# %%
import cudf
cudf.__version__
# Out:
# '25.04.00'

# %%
import cuml
cuml.__version__
# Out:
# '25.04.00'

# %%
import cugraph
cugraph.__version__
# Out:
# '25.04.01'

# %%
import cuspatial
cuspatial.__version__
# Out:
# '25.04.00'

# %%
import cuxfilter
cuxfilter.__version__
# Out:
# '25.04.00'

# %%
# Install Hugging Face Transformers, Datasets, and PyTorch
# !pip install -q transformers datasets evaluate
# !pip install -q accelerate

# (Optional) Check if GPU is available
import torch
print("Torch version:", torch.__version__)
print("GPU available:", torch.cuda.is_available())
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 49.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.8 MB/s eta 0:00:00
# Torch version: 2.6.0+cu124
# GPU available: True

# %%
pip install torch sentencepiece scikit-learn

# %%
# !pip install rouge_score
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=eb2489d2f63a314ecbad04c29051a7062a9d2a919f31a77c1e49c37c0083a264
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# ...

# %%
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration, Trainer, TrainingArguments, DataCollatorForSeq2Seq
from datasets import Dataset, DatasetDict
from sklearn.model_selection import train_test_split
import pandas as pd
import evaluate

# %% [markdown]
# # **Charts**
#
# 🔹 1. Bar & Categorical Charts
#
# Bar Chart
#
# Grouped Bar Chart
#
# Stacked Bar Chart
#
# Horizontal Bar Chart
#
# 🔹 2. Line & Area Charts
#
# Line Chart
#
# Multi-Line Chart
#
# Step Line Chart
#
# Area Chart
#
# Stacked Area Chart
#
# 🔹 3. Distribution & Summary Charts
#
# Histogram
#
# Box Plot
#
# Violin Plot
#
# Pie Chart
#
# Donut Chart
#
# 🔹 4. Business & KPI Charts
#
# Treemap
#
# Waterfall Chart
#
# Funnel Chart
#
# Gauge Chart
#
# KPI Card / Metric
#
# Combo Chart (Bar + Line on Dual Axis)
#
# 🔹 5. Correlation & Relationships
#
# Scatter Plot
#
# Bubble Chart
#
# Correlation Heatmap
#
# 🔹 6. Geographic & Map Visuals
#
# Geo Scatter Map
#
# Choropleth Map

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-291a9a65-e5ad-4e7c-9677-ba03178df599" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-291a9a65-e5ad-4e7c-9677-ba03178df599">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("t5_final_dataset.csv")
df = df.sample(frac=1).reset_index(drop=True)
df = df.rename(columns={"input": "input_text", "target": "target_text"})

# %%
df.head(10)
# Out:
#                                           input_text  \
# 0                        Display coverage on a gauge
# 1    Graph of rainfall across segment, split by city
# 2                        Gauge for tracking accuracy
# 3                         Visualize likes as a gauge
# 4               Visual of program andc licks in bars
# 5   Give bar chart showing device and their humidity
# 6  I want grouped bar of turnover using type grou...
# 7           Donut chart with x = plaftorm, y = votes
# 8  Visualize duration across model in an area cha...
# 9  Visual representation of success_rate across s...
#
#                                          target_text
# 0                          chart: gauge, y: coverage
# 1  chart: grouped_bar, x: segment, y: rainfall, g...
# 2                chart: gauge, y: accuracy, agg: min
# 3                   chart: gauge, y: likes, agg: min
# 4                  chart: bar, x: program, y: clicks
# 5                 chart: bar, x: device, y: humidity
# ...

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# ✅ Load model and tokenizer
model_name = "google/flan-t5-small"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name).to(device)

# ✅ Ensure columns exist
assert "input_text" in df.columns and "target_text" in df.columns, "CSV must have 'input_text' and 'target_text' columns"

# ✅ Train-test split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# ✅ Convert to HuggingFace datasets
train_dataset = Dataset.from_pandas(train_df.reset_index(drop=True))
test_dataset = Dataset.from_pandas(test_df.reset_index(drop=True))
dataset = DatasetDict({"train": train_dataset, "test": test_dataset})

# ✅ Tokenization function using your column names
def preprocess_function(example):
    model_inputs = tokenizer(example["input_text"], max_length=128, truncation=True, padding="max_length")
    labels = tokenizer(example["target_text"], max_length=64, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# ✅ Apply preprocessing
tokenized_datasets = dataset.map(preprocess_function, batched=True)

# ✅ Data collator
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)
# Out:
# Using device: cuda
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ...

# %%
# ✅ Training arguments
training_args = TrainingArguments(
    output_dir="./flan-t5-custom",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    logging_steps=10,
    save_strategy="epoch",
    load_best_model_at_end=False,
    report_to="none"
)

# %%
# ✅ Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# ✅ Train
trainer.train()
# Out:
# /tmp/ipython-input-16-456258762.py:2: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='31620' max='31620' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [31620/31620 49:10, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>27.920300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>21.489000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>17.591300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>12.893900</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>9.476400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>7.623000</td>
#     </tr>
#     <tr>
# ...

# %%
# ✅ Load ROUGE
rouge = evaluate.load("rouge")

# ✅ Evaluation with ROUGE
def evaluate_model_with_rouge(dataset):
    inputs = dataset["input_text"]
    targets = dataset["target_text"]

    predictions = []

    for inp in inputs:
        input_ids = tokenizer(inp, return_tensors="pt", truncation=True, padding=True).input_ids.to(device)
        outputs = model.generate(input_ids, max_length=64)
        pred = tokenizer.decode(outputs[0], skip_special_tokens=True)
        predictions.append(pred)

    results = rouge.compute(predictions=predictions, references=targets, use_stemmer=True)

    print("\n🔍 ROUGE Evaluation:")
    for key, value in results.items():
        print(f"{key}: {value:.4f}")

    print("\n📌 Sample Predictions:")
    for inp, pred, target in zip(inputs, predictions, targets):
        print(f"Input:    {inp}")
        print(f"Target:   {target}")
        print(f"Predicted:{pred}")
        print("---")

# ✅ Call evaluation
evaluate_model_with_rouge(test_dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-20-2989375174.py in <cell line: 0>()
#      29
#      30 # ✅ Call evaluation
# ---> 31 evaluate_model_with_rouge(test_dataset)
#
# /tmp/ipython-input-20-2989375174.py in evaluate_model_with_rouge(dataset)
#      11     for inp in inputs:
#      12         input_ids = tokenizer(inp, return_tensors="pt", truncation=True, padding=True).input_ids.to(device)
# ---> 13         outputs = model.generate(input_ids, max_length=64)
#      14         pred = tokenizer.decode(outputs[0], skip_special_tokens=True)
#      15         predictions.append(pred)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
# ...

# %%
def generate_chart_text(input_text):
    model.eval()  # set to eval mode
    inputs = tokenizer(input_text, return_tensors="pt", truncation=True).input_ids.to(model.device)
    outputs = model.generate(inputs, max_length=64)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Try it!
generate_chart_text("show num_col1 by cat_col1")
# Out:
# 'chart: kpi, y: count'

# %%
model_dir = "flant5-text2chart-tuned"
trainer.save_model(model_dir)
tokenizer.save_pretrained(model_dir)
# Out:
# ('flant5-text2chart-tuned/tokenizer_config.json',
#  'flant5-text2chart-tuned/special_tokens_map.json',
#  'flant5-text2chart-tuned/spiece.model',
#  'flant5-text2chart-tuned/added_tokens.json')

# %%
import shutil

shutil.make_archive('flant5-text2chart-tuned', 'zip', 'flant5-text2chart-tuned')
from google.colab import files
files.download('flant5-text2chart-tuned.zip')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ade17790-8992-4310-ba0c-20b9f9bfdaed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ade17790-8992-4310-ba0c-20b9f9bfdaed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("t5_filter_dataset.csv")
df = df.sample(frac=1).reset_index(drop=True)
df = df.rename(columns={"input": "input_text", "target": "target_text"})

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# ✅ Load model and tokenizer
model_name = "google/flan-t5-small"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name).to(device)

# ✅ Ensure columns exist
assert "input_text" in df.columns and "target_text" in df.columns, "CSV must have 'input_text' and 'target_text' columns"

# ✅ Train-test split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# ✅ Convert to HuggingFace datasets
train_dataset = Dataset.from_pandas(train_df.reset_index(drop=True))
test_dataset = Dataset.from_pandas(test_df.reset_index(drop=True))
dataset = DatasetDict({"train": train_dataset, "test": test_dataset})

# ✅ Tokenization function using your column names
def preprocess_function(example):
    model_inputs = tokenizer(example["input_text"], max_length=128, truncation=True, padding="max_length")
    labels = tokenizer(example["target_text"], max_length=64, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# ✅ Apply preprocessing
tokenized_datasets = dataset.map(preprocess_function, batched=True)

# ✅ Data collator
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)
# Out:
# Using device: cuda
# ...
# Map:   0%|          | 0/240 [00:00<?, ? examples/s]

# %%
# ✅ Training arguments
training_args = TrainingArguments(
    output_dir="./flan-t5-custom",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    logging_steps=100,
    save_strategy="epoch",
    load_best_model_at_end=False,
    report_to="none"
)

# %%
# ✅ Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# ✅ Train
trainer.train()
# Out:
# /tmp/ipython-input-34-456258762.py:2: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='720' max='720' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [720/720 01:10, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.022600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.011200</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.006500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.004900</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.005500</td>
#     </tr>
#     <tr>
#       <td>700</td>
# ...

# %%
# ✅ Load ROUGE
rouge = evaluate.load("rouge")

# ✅ Evaluation with ROUGE
def evaluate_model_with_rouge(dataset):
    inputs = dataset["input_text"]
    targets = dataset["target_text"]

    predictions = []

    for inp in inputs:
        input_ids = tokenizer(inp, return_tensors="pt", truncation=True, padding=True).input_ids.to(device)
        outputs = model.generate(input_ids, max_length=64)
        pred = tokenizer.decode(outputs[0], skip_special_tokens=True)
        predictions.append(pred)

    results = rouge.compute(predictions=predictions, references=targets, use_stemmer=True)

    print("\n🔍 ROUGE Evaluation:")
    for key, value in results.items():
        print(f"{key}: {value:.4f}")

    print("\n📌 Sample Predictions:")
    for inp, pred, target in zip(inputs, predictions, targets):
        print(f"Input:    {inp}")
        print(f"Target:   {target}")
        print(f"Predicted:{pred}")
        print("---")

# ✅ Call evaluation
evaluate_model_with_rouge(test_dataset)
# Out:
# 🔍 ROUGE Evaluation:
# rouge1: 0.9988
# rouge2: 0.9986
# rougeL: 0.9988
# rougeLsum: 0.9988
#
# 📌 Sample Predictions:
# Input:    Extract filters: age != 345
# Target:   column: age; operator: !=; value: 345
# Predicted:column: age; operator: !=; value: 345
# ---
# Input:    Extract filters: rating between 111 and 160
# Target:   column: rating; operator: between; value: 111-160
# Predicted:column: rating; operator: between; value: 111-160
# ---
# Input:    Extract filters: month equals January
# Target:   column: month; operator: ==; value: January
# Predicted:column: month; operator: ==; value: January
# ---
# Input:    Extract filters: region = Europe
# Target:   column: region; operator: ==; value: Europe
# Predicted:column: region; operator: ==; value: Europe
# ---
# Input:    Extract filters: region contains gmail
# Target:   column: region; operator: contains; value: gmail
# Predicted:column: region; operator: contains; value: gmail
# ---
# ...

# %%
model_dir = "flant5-filter-tuned"
trainer.save_model(model_dir)
tokenizer.save_pretrained(model_dir)
# Out:
# ('flant5-filter-tuned/tokenizer_config.json',
#  'flant5-filter-tuned/special_tokens_map.json',
#  'flant5-filter-tuned/spiece.model',
#  'flant5-filter-tuned/added_tokens.json')

# %%
import shutil

shutil.make_archive('flant5-filter-tuned', 'zip', 'flant5-filter-tuned')
from google.colab import files
files.download('flant5-filter-tuned.zip')
